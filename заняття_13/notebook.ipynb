# %%
import re

# %%
text = "Creat product!!"

text = text.lower()
text = re.sub(r"[^a-z\s]", " ", test)
test = re.sub(r"\s+", " ", text)

print(text)

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk.download("punkt")
nltk.download("pu")

# %%
tokens = word_tokenize(text)
print(tokens)

# %%
"The", "capital", "of", "France" => x1, x2, x3, x4 => y1 = "is"

"The", "capital", "of", "France", "is" => x1, x2, x3, x4, x5 => y2 = "Paris"

# %%
nltk.

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

print()

# %%
nltk.download("omw-1.4")
nltk.download("wordnet")
nltk.download("movie-reviews")

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer

lematizer = WordNetLemmatizer()
stemmer = PorterStemmer()

lema = lematizer.lemmatize("cars")
display(stem)

stem = stemmer.stem("internationla")
display(stem)
