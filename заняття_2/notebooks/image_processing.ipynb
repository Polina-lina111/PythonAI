# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image = np.array(Image.open("../../data/cat.webp"))

# %%
print(image.shape)
# Out:
# (280, 292, 3)

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Візуалізація
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
contrast_factor = 128
less_contrast = np.clip(image + contrast_factor, 0, 255).astype(np.uint8)

# %%
# Візуалізація
plt.imshow(less_contrast)
plt.axis("off")
plt.show()
