# %%
print('Hello, World!')

# %% [markdown]
# | Показник  |   Значення   |
# |-----------|:------------:|
# | Середнє   |    1.334     |
#
#
# ## Header 2
#
# * item 1

# %%
my_list = [1, 2, 3, 4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
print(arr)
# Out:
# [1 2 3 4]
