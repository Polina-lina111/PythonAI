# %%
import torch
import torch.nn as nn
from narwhals import dtypes

# %%
arr = torch.tensor([-1.0, 1, 2, 4, 8, 1, 3], dtypes=torch.float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr = torch.tensor([-1.0, 1, 2, 4, 8, 1, 3], dtypes=torch.float32)
#
# TypeError: tensor() got an unexpected keyword argument 'dtypes'

# %%
arr

# %%
softmax = nn.Softmax()

res = softmax(arr)
res

# %% [markdown]
# # Encoder приклади

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analys")

# %%
texts = [
    "The products is easy to use and works well",
    "The delivery was late and the support did not help"
]

# %%
r = classifier()

# %%
r

# %% [markdown]
# Encoder. Summarization

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
model_name = 'google/flan-t5-small'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
article = """
Transformers changed NLP because they made it practical to train large models
on huge text corpora and capture long-range dependencies through attention.
"""

# %%
prompt = "Summarize: " + article

# %%
inputs = tokenizer(prompt, return_tensors="pt")

# %%
outputs = model.generate(**input, max_new_tokens=40, do_sample=False)

# %%
sum
