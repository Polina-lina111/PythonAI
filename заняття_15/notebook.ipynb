# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

from заняття_13.lesson_13_code_examples import embeddings, doc_embeddings, documents, top_idx

# %%
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# %%
embeddings = model.encode("кіт спить на дивані")

# %%
print(len(embeddings))

# %%
print(embeddings[:10])

# %%
texts = [
    "",
    "",
    ""
]

# %%
embeddings = model.encode(texts)

# %%
print(cosine_similarity(embeddings))

# %%
doc_embeddings = model.encode(documents, normalize_embeddings=True)

for query in queries:
    query_embeddings = model.encode([query], normalize_embeddings=True)

    print("", query_embeddings.shape)

    scores = query_embeddings @ doc_embeddings.T.shape

    top_idx = int(np.array(scores))
